# %% [markdown]
# # Export data to spreadsheet
#
# Data in neo4j is exported to a spreadsheet for further analysis.
#
# In neo4j `Respondent` has relationship `CHOSE_ALT` to `QuestionAlternative` which has relationship `CONSISTS_OF` from `Question`.
#
# The `Respondent` has a property `id` which is used to identify the respondent in the spreadsheet.
#
# The `QuestionAlternative` has a property `id` which is used to identify the question alternative in the spreadsheet.
#
# The `QuestionAlternative` has a property `name` which is the text for the alternative.
#
# The `QuestionAlternative` has a property `position` which is the position of the alternative in the question.
#
# The `Question` has a property `id` which is used to identify the question in the spreadsheet.
#
# The `Question` has a property `name` which is the text for the question.
#
# The `Question` has a property `questionCategory` which is the category of the question.
#
# ## Connect to database
#
# Should return version number if successful.

# %%
from databaseconnection import DatabaseConnection

gds = DatabaseConnection().get_database_connection()
gds.version()
# Out:
# '2.3.2'

# %% [markdown]
# ## Query data from database

# %%
# In neo4j `Respondent` has relationship `CHOSE_ALT` to `QuestionAlternative` which has relationship `CONSISTS_OF` from `Question`.

# The `Respondent` has a property `id` which is used to identify the respondent in the spreadsheet.

# The `QuestionAlternative` has a property `id` which is used to identify the question alternative in the spreadsheet.

# The `QuestionAlternative` has a property `name` which is the text for the alternative.

# The `QuestionAlternative` has a property `position` which is the position of the alternative in the question.

# The `Question` has a property `id` which is used to identify the question in the spreadsheet.

# The `Question` has a property `name` which is the text for the question.

# The `Question` has a property `questionType` which is the category of the question.

# The spreadsheet has the following sheets with the follwoing columns:
# Respondent: id, ...(one column for each Question, where the value is the pos for questionAlternative chosen) 
# QuestionAlternative: id, name, position, questionId 
# Question: id, name, questionCategory

result = gds.run_cypher("""
                MATCH (respondent:Respondent)-[:CHOSE_ALT]->(questionAlternative:QuestionAlternative)<-[:CONSISTS_OF]-(question:Question)
                RETURN respondent.id, questionAlternative.id, questionAlternative.name, questionAlternative.position, question.id, question.name, question.questionType
                ORDER BY respondent.id, questionAlternative.id, questionAlternative.position
               """)

print(result.head())
# Out:
#                           respondent.id                questionAlternative.id  \
# 0  00043e30-e387-44de-869b-ad46868697ff  04355686-af25-422e-8473-b7e5c0b20530
# 1  00043e30-e387-44de-869b-ad46868697ff  04d750b1-8543-4843-ab8e-420dc2080b40
# 2  00043e30-e387-44de-869b-ad46868697ff  0a1ddcf0-a35d-4b30-bad4-449aaf3d7216
# 3  00043e30-e387-44de-869b-ad46868697ff  0cba82a7-d632-4db1-b323-7371568d9c88
# 4  00043e30-e387-44de-869b-ad46868697ff  0e03c3b9-0b91-46dc-8f28-5c408a60c456
#
#    questionAlternative.name  questionAlternative.position  \
# 0                       Nej                             1
# 1       Stämmer ganska väl                              1
# 2   Mer än 1 gång i veckan                              1
# 3    Stämmer ganska dåligt                              2
# 4  Ungefär 1 gång i veckan                              2
#
#                             question.id  \
# 0  6a0267b8-5220-4db3-98a6-a0d5bacc5190
# 1  b09df7bd-970f-4b47-be10-4289d90874dc
# 2  4f356252-28f8-430b-b4e5-4dc4be78da2d
# 3  ac9e1f81-f71d-4b00-a1cf-fdc4beb66d78
# 4  3373e70a-726d-442f-a00d-214ff866502c
#
#                                        question.name question.questionType
# 0  Finns det platser på skolan som du tycker är o...      LEADING_QUESTION
# 1  Jag kan vara med någon på rasterna om jag vill...         SINGLE_CHOICE
# 2  Hur ofta har du känt dig nervös eller orolig u...         SINGLE_CHOICE
# 3  Våra lärare har lyckats göra mig nyfiken och i...         SINGLE_CHOICE
# 4  Hur ofta har du varit irriterad eller på dålig...         SINGLE_CHOICE

# %%
print(result.head())
# Out:
#                           respondent.id                questionAlternative.id  \
# 0  00043e30-e387-44de-869b-ad46868697ff  04355686-af25-422e-8473-b7e5c0b20530
# 1  00043e30-e387-44de-869b-ad46868697ff  04d750b1-8543-4843-ab8e-420dc2080b40
# 2  00043e30-e387-44de-869b-ad46868697ff  0a1ddcf0-a35d-4b30-bad4-449aaf3d7216
# 3  00043e30-e387-44de-869b-ad46868697ff  0cba82a7-d632-4db1-b323-7371568d9c88
# 4  00043e30-e387-44de-869b-ad46868697ff  0e03c3b9-0b91-46dc-8f28-5c408a60c456
#
#    questionAlternative.name  questionAlternative.position  \
# 0                       Nej                             1
# 1       Stämmer ganska väl                              1
# 2   Mer än 1 gång i veckan                              1
# 3    Stämmer ganska dåligt                              2
# 4  Ungefär 1 gång i veckan                              2
#
#                             question.id  \
# 0  6a0267b8-5220-4db3-98a6-a0d5bacc5190
# 1  b09df7bd-970f-4b47-be10-4289d90874dc
# 2  4f356252-28f8-430b-b4e5-4dc4be78da2d
# 3  ac9e1f81-f71d-4b00-a1cf-fdc4beb66d78
# 4  3373e70a-726d-442f-a00d-214ff866502c
#
#                                        question.name question.questionType
# 0  Finns det platser på skolan som du tycker är o...      LEADING_QUESTION
# 1  Jag kan vara med någon på rasterna om jag vill...         SINGLE_CHOICE
# 2  Hur ofta har du känt dig nervös eller orolig u...         SINGLE_CHOICE
# 3  Våra lärare har lyckats göra mig nyfiken och i...         SINGLE_CHOICE
# 4  Hur ofta har du varit irriterad eller på dålig...         SINGLE_CHOICE

# %% [markdown]
# ## Generate spreadsheet from dataframe

# %%
# In neo4j `Respondent` has relationship `CHOSE_ALT` to `QuestionAlternative` which has relationship `CONSISTS_OF` from `Question`.

# The `Respondent` has a property `id` which is used to identify the respondent in the spreadsheet.

# The `QuestionAlternative` has a property `id` which is used to identify the question alternative in the spreadsheet.

# The `QuestionAlternative` has a property `name` which is the text for the alternative.

# The `QuestionAlternative` has a property `position` which is the position of the alternative in the question.

# The `Question` has a property `id` which is used to identify the question in the spreadsheet.

# The `Question` has a property `name` which is the text for the question.

# The `Question` has a property `questionType` which is the category of the question.

# The spreadsheet has the following sheets with the follwoing columns:
# Respondent: id, ...(one column for each Question, where the value is the pos for questionAlternative chosen) 
# QuestionAlternative: id, name, position, questionId 
# Question: id, name, questionCategory

import pandas as pd

# Create Respondent dataframe
respondent_df = result.pivot_table(index='respondent.id', columns='question.name', values='questionAlternative.name', aggfunc='first').reset_index()

print(respondent_df.head())
print(respondent_df.columns)
print(respondent_df.shape)

# # Create QuestionAlternative dataframe
# question_alternative_df = result[['questionAlternative.id', 'questionAlternative.name', 'questionAlternative.position', 'question.id', 'question.name']].drop_duplicates()

# print(question_alternative_df.head())
# print(question_alternative_df.columns)
# print(question_alternative_df.shape)

# Create Question dataframe
question_df = result[['question.id', 'question.name', 'questionAlternative.id', 'questionAlternative.name', 'questionAlternative.position']].drop_duplicates()

print(question_df.head())
print(question_df.columns)
print(question_df.shape)

# Export to Excel
with pd.ExcelWriter('output.xlsx') as writer:
    respondent_df.to_excel(writer, index=False, sheet_name='Respondent')
    # question_alternative_df.to_excel(writer, index=False, sheet_name='QuestionAlternative')
    question_df.to_excel(writer, index=False, sheet_name='Question')
# Out:
# question.name                         respondent.id  \
# 0              00043e30-e387-44de-869b-ad46868697ff
# 1              0007c7ae-5ea1-490a-bd5f-c86dfbe41c14
# 2              0039f241-24b8-454a-96a2-ca03aa30dd97
# 3              004f500c-6047-4a5b-9bd1-98e45ca7e791
# 4              006260e3-052a-4521-89aa-517b9bcabe38
#
# question.name  I min(a) klass(er) är det bra stämning   \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
# question.name  I vår klass arbetar eleverna hårt för att lära sig mycket  \
# 0                                         Stämmer ganska dåligt
# 1                                         Stämmer ganska dåligt
# 2                                            Stämmer ganska väl
# 3                                                            NaN
# 4                                         Stämmer ganska dåligt
#
# question.name  I vår klass är det bra stämning  \
# 0                       Stämmer ganska dåligt
# 1                    Vet inte / Kan inte svara
# 2                          Stämmer ganska väl
# 3                                          NaN
# 4                          Stämmer ganska väl
#
# question.name  I vår klass är eleverna omtänksamma mot varandra   \
# 0                                            Stämmer ganska väl
# 1                                      Vet inte / Kan inte svara
# 2                                            Stämmer ganska väl
# 3                                                            NaN
# 4                                            Stämmer ganska väl
#
# question.name  I vår klass är klassreglerna framtagna gemensamt av elever och lärare  \
# 0                                         Stämmer ganska dåligt
# 1                                         Stämmer ganska dåligt
# 2                                         Stämmer ganska dåligt
# 3                                                            NaN
# 4                                         Stämmer ganska dåligt
#
# question.name  I vår skola följer de flesta eleverna skolans regler  \
# 0                                         Stämmer ganska dåligt
# 1                                         Stämmer ganska dåligt
# 2                                            Stämmer ganska väl
# 3                                                            NaN
# 4                                            Stämmer ganska väl
#
# question.name A.\tTänk på hur du har haft det i skolan och på väg till och från skolan de senaste 2-3 månaderna.  Har du känt dig ledsen, sårad, rädd eller arg, av att andra ELEVER har slagit, sparkat, knuffat, hållit fast, stängt in dig eller hotat dig med vapen?  \
# 0                                     Nej, det har inte hänt mig
# 1                                     Nej, det har inte hänt mig
# 2                                     Nej, det har inte hänt mig
# 3                                                            NaN
# 4                                                 Ja, någon gång
#
# question.name A. Jag har under de senaste 2-3 månaderna upplevt obehag (känt mig ledsen, sårad, rädd eller arg) av att andra ELEVER har slagit, sparkat, knuffat, hållit fast, låst in eller stängt in mig i SKOLAN, på skolgården eller på väg till/från skolan  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                                 Ja, någon gång
# 4                                                            NaN
#
# question.name AKTIVA ÅTGÄRDER MOT DISKRIMINERING:  Aktiva åtgärder innebär att skolan arbetar för att motverka diskriminering och främja lika rättigheter och möjligheter för barn och elever i verksamheten. Exempelvis ska skolor arbeta fortlöpande i fyra steg med att 1) undersöka risker för diskriminering, 2) analysera orsaker, 3) genomföra åtgärder och 4) följa upp och utvärdera. Det ska finnas riktlinjer och rutiner för sexuella trakasserier och trakasserier. Allt detta ska därtill dokumenteras  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4                                                            NaN
#
# question.name  ...  \
# 0              ...
# 1              ...
# 2              ...
# 3              ...
# 4              ...
#
# question.name Vår skola har en plan mot kränkande behandling som revideras varje år  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4                                                            NaN
#
# question.name Våra lärare behandlar eleverna rättvist  \
# 0                                 Stämmer ganska väl
# 1                              Stämmer ganska dåligt
# 2                                 Stämmer ganska väl
# 3                                 Stämmer mycket väl
# 4                                 Stämmer mycket väl
#
# question.name Våra lärare ger oss elever bra stöd och hjälp  \
# 0                                                       NaN
# 1                                                       NaN
# 2                                                       NaN
# 3                                       Stämmer ganska väl
# 4                                                       NaN
#
# question.name Våra lärare ger oss elever bra stöd och hjälp i klassrummet  \
# 0                                         Stämmer ganska dåligt
# 1                                      Vet inte / Kan inte svara
# 2                                            Stämmer mycket väl
# 3                                                            NaN
# 4                                      Vet inte / Kan inte svara
#
# question.name Våra lärare har lyckats göra mig nyfiken och intresserad av ämnen som jag till en början inte alls var intresserad av  \
# 0                                         Stämmer ganska dåligt
# 1                                         Stämmer mycket dåligt
# 2                                            Stämmer ganska väl
# 3                                            Stämmer mycket väl
# 4                                      Vet inte / Kan inte svara
#
# question.name Våra lärare lyssnar uppmärksamt när jag eller mina klasskamrater frågar dem om något  \
# 0                                                            NaN
# 1                                                            NaN
# 2                                                            NaN
# 3                                            Stämmer mycket väl
# 4                                                            NaN
#
# question.name Våra lärare skapar ordning och arbetsro i klassrummet  \
# 0                                         Stämmer ganska dåligt
# 1                                      Vet inte / Kan inte svara
# 2                                         Stämmer ganska dåligt
# 3                                            Stämmer ganska väl
# 4                                            Stämmer ganska väl
#
# question.name Våra lärare ställer tydliga krav på oss elever  \
# 0                                        Stämmer ganska väl
# 1                                        Stämmer ganska väl
# 2                                        Stämmer ganska väl
# 3                                        Stämmer mycket väl
# 4                                  Vet inte / Kan inte svara
#
# question.name Våra lärare säger till de elever som stör undervisningen  \
# 0                                            Stämmer ganska väl
# 1                                            Stämmer ganska väl
# 2                                         Stämmer ganska dåligt
# 3                                                            NaN
# 4                                      Vet inte / Kan inte svara
#
# question.name Våra lärare tar sig tid att berätta för mig hur det går för mig i skolan
# 0                                         Stämmer mycket dåligt
# 1                                      Vet inte / Kan inte svara
# 2                                            Stämmer ganska väl
# 3                                            Stämmer mycket väl
# 4                                      Vet inte / Kan inte svara
#
# [5 rows x 233 columns]
# Index(['respondent.id', ' I min(a) klass(er) är det bra stämning ',
#        ' I vår klass arbetar eleverna hårt för att lära sig mycket',
#        ' I vår klass är det bra stämning',
#        ' I vår klass är eleverna omtänksamma mot varandra ',
#        ' I vår klass är klassreglerna framtagna gemensamt av elever och lärare',
#        ' I vår skola följer de flesta eleverna skolans regler',
#        'A.\tTänk på hur du har haft det i skolan och på väg till och från skolan de senaste 2-3 månaderna.  Har du känt dig ledsen, sårad, rädd eller arg, av att andra ELEVER har slagit, sparkat, knuffat, hållit fast, stängt in dig eller hotat dig med vapen?',
#        'A. Jag har under de senaste 2-3 månaderna upplevt obehag (känt mig ledsen, sårad, rädd eller arg) av att andra ELEVER har slagit, sparkat, knuffat, hållit fast, låst in eller stängt in mig i SKOLAN, på skolgården eller på väg till/från skolan',
#        'AKTIVA ÅTGÄRDER MOT DISKRIMINERING:  Aktiva åtgärder innebär att skolan arbetar för att motverka diskriminering och främja lika rättigheter och möjligheter för barn och elever i verksamheten. Exempelvis ska skolor arbeta fortlöpande i fyra steg med att 1) undersöka risker för diskriminering, 2) analysera orsaker, 3) genomföra åtgärder och 4) följa upp och utvärdera. Det ska finnas riktlinjer och rutiner för sexuella trakasserier och trakasserier. Allt detta ska därtill dokumenteras',
#        ...
#        'Vår skola har en plan mot kränkande behandling som revideras varje år',
#        'Våra lärare behandlar eleverna rättvist',
#        'Våra lärare ger oss elever bra stöd och hjälp',
#        'Våra lärare ger oss elever bra stöd och hjälp i klassrummet',
#        'Våra lärare har lyckats göra mig nyfiken och intresserad av ämnen som jag till en början inte alls var intresserad av',
#        'Våra lärare lyssnar uppmärksamt när jag eller mina klasskamrater frågar dem om något',
#        'Våra lärare skapar ordning och arbetsro i klassrummet',
#        'Våra lärare ställer tydliga krav på oss elever',
#        'Våra lärare säger till de elever som stör undervisningen',
#        'Våra lärare tar sig tid att berätta för mig hur det går för mig i skolan'],
#       dtype='object', name='question.name', length=233)
# (3466, 233)
#                             question.id  \
# 0  6a0267b8-5220-4db3-98a6-a0d5bacc5190
# 1  b09df7bd-970f-4b47-be10-4289d90874dc
# 2  4f356252-28f8-430b-b4e5-4dc4be78da2d
# 3  ac9e1f81-f71d-4b00-a1cf-fdc4beb66d78
# 4  3373e70a-726d-442f-a00d-214ff866502c
#
#                                        question.name  \
# 0  Finns det platser på skolan som du tycker är o...
# 1  Jag kan vara med någon på rasterna om jag vill...
# 2  Hur ofta har du känt dig nervös eller orolig u...
# 3  Våra lärare har lyckats göra mig nyfiken och i...
# 4  Hur ofta har du varit irriterad eller på dålig...
#
#                  questionAlternative.id  questionAlternative.name  \
# 0  04355686-af25-422e-8473-b7e5c0b20530                       Nej
# 1  04d750b1-8543-4843-ab8e-420dc2080b40       Stämmer ganska väl
# 2  0a1ddcf0-a35d-4b30-bad4-449aaf3d7216   Mer än 1 gång i veckan
# 3  0cba82a7-d632-4db1-b323-7371568d9c88    Stämmer ganska dåligt
# 4  0e03c3b9-0b91-46dc-8f28-5c408a60c456  Ungefär 1 gång i veckan
#
#    questionAlternative.position
# 0                             1
# 1                             1
# 2                             1
# 3                             2
# 4                             2
# Index(['question.id', 'question.name', 'questionAlternative.id',
#        'questionAlternative.name', 'questionAlternative.position'],
#       dtype='object')
# (1325, 5)
